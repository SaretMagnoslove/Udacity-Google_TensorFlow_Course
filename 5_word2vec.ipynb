# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.169407
# Nearest to two: yupik, harming, eschewing, ergative, councillor, freeware, hooke, contemporaneous,
# Nearest to called: hindemith, thickness, labs, distinctly, celled, flexible, hoof, shear,
# Nearest to to: liddell, egerton, subtree, holger, encyclopedias, ophile, errico, demonstrates,
# Nearest to system: ethelred, driver, natured, investigations, competitively, dismantling, balti, contrasted,
# Nearest to seven: trypomastigotes, voroshilov, hashanah, forth, sahrawi, airport, resident, universally,
# Nearest to with: albert, caricatures, zagreb, fenton, personal, cowl, facie, hoist,
# Nearest to d: redneck, buell, tulip, brigitte, farragut, fairbanks, simulations, possum,
# Nearest to s: boerhaave, unspecific, pal, xml, tnt, dew, morocco, assyrian,
# Nearest to be: militiamen, airmen, nearly, dimensionally, dowager, truthful, longstreet, biscay,
# Nearest to his: schulz, octaves, daley, szczecin, insert, ovation, conspiracy, indications,
# Nearest to also: canadian, berkowitz, leeward, insecurity, conciliation, unleashed, matter, exemptions,
# Nearest to one: metz, aboriginal, breuer, mayall, refracting, influential, patriarchy, mervyn,
# Nearest to state: hh, north, catalan, salvage, tuva, lott, malinowski, inning,
# Nearest to up: options, rickshaw, polytheism, lesbos, armada, octal, angels, disarmament,
# Nearest to he: ivy, strassman, kimchi, lustrous, obsidian, dosage, ammo, memoir,
# Nearest to only: chameleon, evoked, salvaged, walley, ned, custom, fuelled, liebig,
# Average loss at step 2000: 4.373010
# Average loss at step 4000: 3.865550
# Average loss at step 6000: 3.792811
# Average loss at step 8000: 3.694781
# Average loss at step 10000: 3.613204
# Nearest to two: three, five, four, six, eight, seven, nine, zero,
# Nearest to called: thickness, hindemith, dagome, andy, researched, qian, seif, conservation,
# Nearest to to: not, will, humor, liddell, climatology, would, nemours, demonstrates,
# Nearest to system: driver, competitively, investigations, natured, counting, catastrophic, patrician, settler,
# Nearest to seven: six, eight, three, five, four, nine, zero, two,
# Nearest to with: portrayals, between, thymus, personal, biddle, for, libido, inspires,
# Nearest to d: recife, redneck, frederic, baekje, tipton, mariana, fulvia, disarmed,
# Nearest to s: his, encyclopedia, and, beira, hyperinflation, quarrels, rudi, sculptures,
# Nearest to be: have, militiamen, are, terrific, was, eddington, maia, barbagia,
# Nearest to his: their, the, her, s, anvil, its, nitrogen, dreamworks,
# Nearest to also: which, it, who, there, insecurity, sometimes, canadian, archbishopric,
# Nearest to one: two, six, three, seven, four, storm, five, bis,
# Nearest to state: hh, north, catalan, pakistan, jehoahaz, widehat, chording, war,
# Nearest to up: options, lesbos, superlatives, superpowers, prostitutes, him, tranquility, accommodation,
# Nearest to he: it, she, they, strassman, there, dahomey, triumphal, renewing,
# Nearest to only: chameleon, henning, liebig, viet, nonprofit, laban, evoked, possible,
# Average loss at step 12000: 3.605370
# Average loss at step 14000: 3.573988
# Average loss at step 16000: 3.413753
# Average loss at step 18000: 3.461207
# Average loss at step 20000: 3.545569
# Nearest to two: four, three, five, six, eight, seven, one, nine,
# Nearest to called: thickness, see, under, unsure, significantly, normality, hoof, my,
# Nearest to to: will, would, can, could, not, nemours, may, demonstrates,
# Nearest to system: competitively, investigations, counting, exists, driver, proprietor, treasury, previous,
# Nearest to seven: eight, nine, five, six, four, three, two, zero,
# Nearest to with: between, personal, biddle, thymus, libido, owes, by, in,
# Nearest to d: b, tipton, fulvia, possum, halmos, frederic, decipher, recife,
# Nearest to s: husk, motors, interlingua, nominees, edna, encyclopedia, hyperinflation, flavianum,
# Nearest to be: have, been, refer, were, by, was, is, ruble,
# Nearest to his: their, her, its, the, anvil, dreamworks, profusion, hine,
# Nearest to also: not, sometimes, which, often, it, now, who, sveriges,
# Nearest to one: four, two, three, seven, six, eight, five, nine,
# Nearest to state: hh, jehoahaz, catalan, sacrificing, bodybuilding, widehat, zealot, squash,
# Nearest to up: options, him, oranges, lesbos, tranquility, superlatives, busting, odors,
# Nearest to he: it, she, they, who, there, prejudice, never, dahomey,
# Nearest to only: aonb, henning, nonprofit, evoked, possible, it, sensei, divided,
# Average loss at step 22000: 3.499955
# Average loss at step 24000: 3.494209
# Average loss at step 26000: 3.477034
# Average loss at step 28000: 3.484182
# Average loss at step 30000: 3.505643
# Nearest to two: four, three, six, one, five, seven, eight, nine,
# Nearest to called: andy, see, normality, thickness, printed, hoof, referred, seif,
# Nearest to to: would, will, can, charting, humor, repercussions, irrationality, cathy,
# Nearest to system: systems, informer, investigations, palo, proceeding, patrician, competitively, contrasted,
# Nearest to seven: eight, nine, four, six, five, three, zero, two,
# Nearest to with: between, in, personal, thymus, by, biddle, traversal, worthington,
# Nearest to d: b, tipton, halmos, possum, frederic, guano, fulvia, bacterium,
# Nearest to s: his, husk, interlingua, contemplates, azerbaijan, adour, jutsu, medal,
# Nearest to be: have, refer, been, were, are, was, is, hijacked,
# Nearest to his: her, their, its, the, s, anvil, hine, my,
# Nearest to also: often, sometimes, now, it, which, never, still, who,
# Nearest to one: two, seven, four, six, eight, three, five, nine,
# Nearest to state: jehoahaz, states, sacrificing, city, widehat, eleven, prescribing, hh,
# Nearest to up: him, them, options, lesbos, out, oranges, accommodation, off,
# Nearest to he: it, she, they, who, there, never, originally, prejudice,
# Nearest to only: rinse, hexagon, libby, divided, possible, nonprofit, about, henning,
# Average loss at step 32000: 3.500736
# Average loss at step 34000: 3.491408
# Average loss at step 36000: 3.455218
# Average loss at step 38000: 3.303794
# Average loss at step 40000: 3.431968
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to called: referred, see, named, andy, thickness, jardine, normality, hoof,
# Nearest to to: can, could, may, will, t, parkinson, raster, thymus,
# Nearest to system: systems, investigations, proceeding, counting, resh, informer, contrasted, orpheus,
# Nearest to seven: eight, nine, five, six, four, three, zero, two,
# Nearest to with: between, thymus, by, when, myrdal, in, ecologically, grassroots,
# Nearest to d: b, tipton, UNK, possum, c, browse, halmos, guano,
# Nearest to s: his, their, nullify, medal, adour, interacted, husk, lockport,
# Nearest to be: been, have, refer, was, are, become, were, is,
# Nearest to his: their, her, its, the, s, my, psychologists, hine,
# Nearest to also: often, which, sometimes, usually, now, still, never, actually,
# Nearest to one: two, seven, six, eight, four, five, nine, three,
# Nearest to state: jehoahaz, widehat, government, city, sacrificing, states, competitive, hh,
# Nearest to up: him, them, out, off, back, options, down, accommodation,
# Nearest to he: she, it, they, there, who, nemesis, this, misquoted,
# Nearest to only: divided, strictly, nonprofit, libby, hexagon, conformation, it, still,
# Average loss at step 42000: 3.430524
# Average loss at step 44000: 3.454845
# Average loss at step 46000: 3.452679
# Average loss at step 48000: 3.356048
# Average loss at step 50000: 3.383154
# Nearest to two: three, one, four, six, five, eight, seven, nine,
# Nearest to called: named, jardine, referred, see, stf, printed, thereupon, normality,
# Nearest to to: can, would, may, foreskin, infant, acuity, musk, mueller,
# Nearest to system: systems, proceeding, twinned, investigations, bridal, dismantling, proprietor, annunciation,
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to with: between, inspires, ux, thymus, wig, pods, wicklow, by,
# Nearest to d: b, tipton, possum, halmos, embellished, standalone, guano, mariana,
# Nearest to s: whose, his, nullify, and, adour, consuls, stanis, liaison,
# Nearest to be: have, refer, was, were, been, being, is, become,
# Nearest to his: their, her, its, my, hine, our, the, s,
# Nearest to also: often, which, now, actually, sometimes, here, usually, still,
# Nearest to one: two, eight, six, four, seven, nine, three, five,
# Nearest to state: jehoahaz, sacrificing, government, states, widehat, national, city, municipal,
# Nearest to up: out, off, him, them, down, back, accommodation, options,
# Nearest to he: she, it, they, who, there, this, officially, never,
# Nearest to only: homicides, nonprofit, divided, dimmer, still, henning, strictly, babes,
# Average loss at step 52000: 3.436805
# Average loss at step 54000: 3.427920
# Average loss at step 56000: 3.440262
# Average loss at step 58000: 3.399504
# Average loss at step 60000: 3.393325
# Nearest to two: three, four, five, one, six, eight, seven, nine,
# Nearest to called: named, known, referred, used, considered, see, thereupon, printed,
# Nearest to to: would, may, will, must, can, not, only, towards,
# Nearest to system: systems, investigations, programs, bridal, proceeding, twinned, treasury, proprietor,
# Nearest to seven: eight, four, six, nine, five, three, one, zero,
# Nearest to with: between, biddle, libido, into, in, traversal, kleist, by,
# Nearest to d: b, c, tipton, j, p, possum, embellished, h,
# Nearest to s: dios, whose, flavianum, hyperinflation, gtk, bg, entailed, enfant,
# Nearest to be: been, refer, was, have, become, were, is, being,
# Nearest to his: her, their, its, my, hine, the, yorkist, favour,
# Nearest to also: often, actually, now, still, sometimes, which, usually, below,
# Nearest to one: two, seven, eight, six, four, five, three, nine,
# Nearest to state: jehoahaz, states, government, widehat, baronet, majority, city, corporate,
# Nearest to up: out, off, him, them, down, back, accommodation, oranges,
# Nearest to he: she, it, they, there, who, nemesis, later, we,
# Nearest to only: always, until, homicides, archipelagoes, divided, transl, nonprofit, first,
# Average loss at step 62000: 3.241670
# Average loss at step 64000: 3.254442
# Average loss at step 66000: 3.403100
# Average loss at step 68000: 3.395732
# Average loss at step 70000: 3.361385
# Nearest to two: three, four, six, one, seven, five, eight, zero,
# Nearest to called: named, stf, considered, see, known, referred, athenaeum, humphreys,
# Nearest to to: can, must, cannot, could, bamboo, would, will, acuity,
# Nearest to system: systems, programs, investigations, sentinel, bridal, hazards, kq, resh,
# Nearest to seven: six, eight, nine, four, five, three, two, zero,
# Nearest to with: between, traversal, into, libido, in, luxuries, biddle, worthington,
# Nearest to d: b, tipton, possum, halmos, louise, clause, ar, guano,
# Nearest to s: whose, interlingua, bg, tonne, athleticism, should, husk, consuls,
# Nearest to be: been, become, is, refer, being, have, were, was,
# Nearest to his: her, their, its, my, our, the, yorkist, shadowrun,
# Nearest to also: often, still, actually, which, now, usually, never, sometimes,
# Nearest to one: two, six, four, seven, eight, five, three, nine,
# Nearest to state: states, city, government, widehat, jehoahaz, sacrificing, headlines, patton,
# Nearest to up: off, them, out, down, him, back, oranges, accommodation,
# Nearest to he: she, it, they, there, who, we, never, stems,
# Nearest to only: still, henning, technically, nonprofit, homicides, transl, parochial, another,
# Average loss at step 72000: 3.376437
# Average loss at step 74000: 3.347140
# Average loss at step 76000: 3.317776
# Average loss at step 78000: 3.349963
# Average loss at step 80000: 3.380022
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to called: named, known, stf, used, referred, considered, see, besson,
# Nearest to to: acuity, would, will, climatology, bamboo, fax, charting, cannot,
# Nearest to system: systems, programs, investigations, resh, bridal, interactions, sentinel, gas,
# Nearest to seven: six, eight, five, nine, four, three, zero, one,
# Nearest to with: between, thymus, when, in, containing, traversal, during, laurentian,
# Nearest to d: b, tipton, possum, balkh, volume, halmos, louise, brigitte,
# Nearest to s: euskara, bg, interlingua, flavianum, maria, falsification, rcr, musings,
# Nearest to be: been, have, being, refer, become, easily, are, were,
# Nearest to his: her, their, my, our, its, the, your, personifications,
# Nearest to also: often, actually, still, now, never, usually, which, sometimes,
# Nearest to one: seven, two, six, four, three, eight, five, nine,
# Nearest to state: states, city, widehat, jehoahaz, government, headlines, sacrificing, courts,
# Nearest to up: out, off, them, down, him, back, oranges, gordian,
# Nearest to he: she, it, they, there, who, we, never, later,
# Nearest to only: homicides, nonprofit, transl, still, technically, always, henning, last,
# Average loss at step 82000: 3.408186
# Average loss at step 84000: 3.408874
# Average loss at step 86000: 3.390532
# Average loss at step 88000: 3.352793
# Average loss at step 90000: 3.363527
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to called: named, used, considered, known, referred, stf, humphreys, besson,
# Nearest to to: towards, would, fax, tutu, acuity, mahoney, will, could,
# Nearest to system: systems, kq, process, investigations, bridal, rearden, proceeding, hazards,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to with: between, thymus, in, myrdal, traversal, cameroun, by, pods,
# Nearest to d: b, louise, mariana, vlsi, possum, hemorrhage, h, tipton,
# Nearest to s: whose, tonne, bg, medal, toronto, his, isbn, patricia,
# Nearest to be: been, have, become, was, refer, being, is, easily,
# Nearest to his: her, their, its, my, our, the, your, bridgehead,
# Nearest to also: often, still, actually, now, which, never, sometimes, generally,
# Nearest to one: seven, two, four, eight, six, three, five, nine,
# Nearest to state: city, states, jehoahaz, government, widehat, majority, student, headlines,
# Nearest to up: off, out, down, them, him, back, away, nihilistic,
# Nearest to he: she, it, they, there, who, we, later, originally,
# Nearest to only: homicides, even, another, actually, no, trilled, gora, divided,
# Average loss at step 92000: 3.404590
# Average loss at step 94000: 3.256006
# Average loss at step 96000: 3.352706
# Average loss at step 98000: 3.243320
# Average loss at step 100000: 3.361624
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to called: named, known, used, considered, referred, stf, humphreys, see,
# Nearest to to: will, would, cannot, could, may, must, should, acuity,
# Nearest to system: systems, process, bridal, kq, programs, investigations, proceeding, confidentiality,
# Nearest to seven: eight, six, four, nine, five, three, two, zero,
# Nearest to with: between, traversal, thymus, containing, including, despite, when, in,
# Nearest to d: b, tipton, halmos, louise, clause, j, r, y,
# Nearest to s: whose, adour, his, my, flavianum, maria, seahawks, pomona,
# Nearest to be: been, refer, being, become, have, is, are, easily,
# Nearest to his: her, their, my, its, our, your, the, djvu,
# Nearest to also: actually, still, now, never, often, sometimes, which, usually,
# Nearest to one: two, seven, four, six, three, eight, five, nine,
# Nearest to state: city, states, jehoahaz, headlines, widehat, government, student, heliports,
# Nearest to up: out, off, down, them, him, back, gren, nihilistic,
# Nearest to he: she, they, it, there, we, who, never, i,
# Nearest to only: homicides, another, even, technically, strictly, no, actually, until,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as sess:
    tf.initialize_all_variables().run()
    print('Ini Ini Initialized')
    average_loss = 0
    for step in range(num_steps):
   
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = sess.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From c:\users\avi\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\util\tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Ini Ini Initialized
# Average loss at step 0: 8.062649
# Nearest to two: fairfax, recruiting, gaddis, security, meo, posthuman, wagers, heidegger,
# Nearest to called: sanitarium, diamondbacks, wakes, fuzzy, revision, farragut, firearms, mccain,
# Nearest to to: nutation, antiquark, langmuir, mercalli, accomplish, paleontology, flare, lucrative,
# Nearest to system: inhibiting, nueva, ditko, siddhartha, eamonn, sparks, earnhardt, fugal,
# Nearest to seven: daffodils, hallucinogenic, vasco, soldering, readiness, compost, respectable, settler,
# Nearest to with: preach, arbuckle, verbally, moab, possesses, almagro, ephemerides, subsequently,
# Nearest to d: coven, ortho, gatwick, norris, auckland, regulars, timber, poetry,
# Nearest to s: bilateral, tides, fireplace, galton, charge, analyse, osvaldo, encodings,
# Nearest to be: denard, agitating, clad, guilty, pee, gangrene, gundam, displeasure,
# Nearest to his: construed, establishes, countably, raves, attainable, paramagnetic, costello, carlist,
# Nearest to also: sardis, barracuda, eaton, sampras, ler, rejoining, overthrown, ningen,
# Nearest to one: mersenne, olympias, chorales, prince, chaitin, disappeared, bak, dissenters,
# Nearest to state: giovanni, proceedings, ayn, eli, canned, vast, atlantean, libel,
# Nearest to up: chin, fluffy, nihilo, diskettes, sayings, nazi, vitamins, subsidies,
# Nearest to he: hadadezer, seed, counterrevolutionary, bamar, hieroglyphs, aberdeen, crocodile, opportunities,
# Nearest to only: multicellular, vanadium, suspends, vara, hurricanes, direct, essential, gower,
# Average loss at step 2000: 4.377461
# Average loss at step 4000: 3.873727
# Average loss at step 6000: 3.796798
# Average loss at step 8000: 3.758635
# Average loss at step 10000: 3.626104
# Nearest to two: three, one, seven, four, six, five, eight, zero,
# Nearest to called: while, propellant, sanitarium, outfielders, diamondbacks, gunpoint, exact, mccain,
# Nearest to to: nutation, attain, langmuir, can, counsels, with, and, applets,
# Nearest to system: inhibiting, nueva, sheaf, steam, sparks, activists, prehistoric, earnhardt,
# Nearest to seven: eight, six, five, three, nine, four, one, two,
# Nearest to with: in, on, by, kamakura, for, into, minimalism, between,
# Nearest to d: b, auckland, rix, norris, individually, narrators, reared, fidonet,
# Nearest to s: liturgy, incapable, his, harbin, the, diversity, ariane, cabin,
# Nearest to be: have, was, are, by, been, mingle, displeasure, were,
# Nearest to his: their, its, the, her, colonize, raised, loy, tic,
# Nearest to also: it, often, he, who, which, habitations, sardis, argued,
# Nearest to one: two, three, seven, six, eight, four, five, nine,
# Nearest to state: giovanni, partner, noaa, canned, libel, proceedings, atlantean, diametrically,
# Nearest to up: latte, nazi, adjunct, poodle, rectangles, redacted, nihilo, foresee,
# Nearest to he: it, she, they, who, also, consequential, ben, babbage,
# Nearest to only: shortness, oblivious, vara, quisling, beeswax, zhang, direct, strawberries,
# Average loss at step 12000: 3.582954
# Average loss at step 14000: 3.614735
# Average loss at step 16000: 3.590843
# Average loss at step 18000: 3.570590
# Average loss at step 20000: 3.545803
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to called: gunpoint, notated, nationalism, cocos, propellant, sanitarium, while, excuse,
# Nearest to to: can, nutation, langmuir, will, for, would, into, should,
# Nearest to system: inhibiting, nueva, systems, prehistoric, sparks, milgram, activists, vanguard,
# Nearest to seven: eight, five, six, nine, four, three, zero, one,
# Nearest to with: between, hillsdale, into, dedekind, libyans, in, by, minimalism,
# Nearest to d: b, fidonet, v, auckland, bumpy, rix, individually, norris,
# Nearest to s: his, ineffectiveness, and, fleece, individually, cautions, grampus, incapable,
# Nearest to be: have, by, been, are, were, recombine, mingle, approach,
# Nearest to his: their, her, its, the, s, tic, our, loy,
# Nearest to also: which, often, usually, still, it, habitations, who, below,
# Nearest to one: seven, eight, two, six, four, nine, five, three,
# Nearest to state: analyse, totals, noaa, giovanni, diametrically, emanation, spaced, fdp,
# Nearest to up: rectangles, them, latte, nihilo, poodle, hyena, adjunct, foresee,
# Nearest to he: it, she, they, who, there, this, consequential, acadia,
# Nearest to only: shortness, overviews, surprise, eta, oblivious, humane, grid, zenith,
# Average loss at step 22000: 3.530425
# Average loss at step 24000: 3.447076
# Average loss at step 26000: 3.419039
# Average loss at step 28000: 3.478721
# Average loss at step 30000: 3.408693
# Nearest to two: three, four, six, seven, five, eight, zero, dissipation,
# Nearest to called: gunpoint, excuse, attributed, highlighting, cocos, considered, eastbound, bakkers,
# Nearest to to: nutation, langmuir, will, would, for, enterprising, should, attain,
# Nearest to system: systems, inhibiting, prehistoric, activists, nueva, organization, purpose, codeine,
# Nearest to seven: six, eight, five, four, nine, three, two, zero,
# Nearest to with: between, dedekind, by, into, in, against, libyans, and,
# Nearest to d: b, american, peter, individually, fidonet, auckland, lobos, regulars,
# Nearest to s: ineffectiveness, cabin, and, unrequited, his, fleece, bilateral, mestre,
# Nearest to be: been, have, is, by, being, were, refer, approach,
# Nearest to his: her, their, its, the, wyclif, loy, s, akan,
# Nearest to also: often, which, usually, below, still, now, antennae, sampras,
# Nearest to one: six, spinners, four, seven, eight, goran, prions, ziggy,
# Nearest to state: emanation, totals, giovanni, national, awesome, partner, dominatrix, fdp,
# Nearest to up: them, out, rectangles, latte, abruptly, nihilo, hyena, foresee,
# Nearest to he: she, it, they, who, there, consequential, candide, eventually,
# Nearest to only: listens, shortness, oblivious, adopt, taverns, admirer, speller, humane,
# Average loss at step 32000: 3.420914
# Average loss at step 34000: 3.441028
# Average loss at step 36000: 3.367283
# Average loss at step 38000: 3.497886
# Average loss at step 40000: 3.444459
# Nearest to two: three, four, five, six, seven, zero, eight, one,
# Nearest to called: gunpoint, considered, puts, attributed, salsa, cocos, highlighting, excuse,
# Nearest to to: nutation, silvanus, langmuir, must, will, could, can, would,
# Nearest to system: systems, activists, inhibiting, gau, hail, worthwhile, organization, philosophicus,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to with: between, libyans, when, against, mosquitoes, into, dedekind, gotland,
# Nearest to d: b, atacama, v, aberdare, fidonet, sutherland, p, affiliations,
# Nearest to s: his, was, ineffectiveness, fleece, trout, decoration, their, its,
# Nearest to be: been, have, was, being, by, were, is, refer,
# Nearest to his: her, their, its, s, the, my, our, loy,
# Nearest to also: often, usually, which, still, now, below, antennae, sometimes,
# Nearest to one: seven, two, six, three, eight, four, five, nine,
# Nearest to state: emanation, national, states, giovanni, totals, xuan, awesome, partner,
# Nearest to up: out, off, them, rectangles, hyena, latte, nihilo, down,
# Nearest to he: it, she, they, who, there, we, eventually, gmc,
# Nearest to only: listens, conglomerate, businessmen, artur, shortness, visa, montoneros, adopt,
# Average loss at step 42000: 3.425951
# Average loss at step 44000: 3.284904
# Average loss at step 46000: 3.412390
# Average loss at step 48000: 3.434193
# Average loss at step 50000: 3.436900
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to called: gunpoint, considered, used, attributed, petrochemicals, salsa, newington, named,
# Nearest to to: would, will, langmuir, nutation, should, must, could, may,
# Nearest to system: systems, inhibiting, activists, gau, position, philosophicus, gcc, organization,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to with: between, in, libyans, against, and, lombardi, among, dominican,
# Nearest to d: b, v, m, r, fidonet, sutherland, affiliations, selenium,
# Nearest to s: whose, and, his, ineffectiveness, decomposing, connectives, bilateral, reappeared,
# Nearest to be: been, have, refer, become, take, was, recombine, is,
# Nearest to his: her, their, its, the, my, our, your, s,
# Nearest to also: often, which, now, usually, still, antennae, always, below,
# Nearest to one: two, five, seven, four, three, six, eight, nine,
# Nearest to state: states, emanation, presidents, national, giovanni, awesome, creation, heathen,
# Nearest to up: out, them, down, off, hyena, rectangles, nihilo, back,
# Nearest to he: she, it, they, who, there, we, warwick, eventually,
# Nearest to only: conglomerate, listens, first, all, artur, businessmen, last, montoneros,
# Average loss at step 52000: 3.458323
# Average loss at step 54000: 3.431385
# Average loss at step 56000: 3.404653
# Average loss at step 58000: 3.281831
# Average loss at step 60000: 3.389200
# Nearest to two: three, five, four, seven, eight, six, one, nine,
# Nearest to called: attributed, used, named, considered, gunpoint, newington, counterexamples, terrestrial,
# Nearest to to: nutation, would, langmuir, could, will, from, across, should,
# Nearest to system: systems, inhibiting, gau, position, leased, enforced, selenium, willed,
# Nearest to seven: eight, five, six, four, nine, three, two, zero,
# Nearest to with: between, against, libyans, among, dedekind, lombardi, by, including,
# Nearest to d: b, v, aberdare, fidonet, selenium, affiliations, uralic, m,
# Nearest to s: reappeared, connectives, his, whose, ineffectiveness, isbn, minarets, and,
# Nearest to be: been, become, have, was, refer, were, is, are,
# Nearest to his: her, their, its, the, our, your, my, s,
# Nearest to also: which, often, now, who, antennae, still, usually, officially,
# Nearest to one: two, four, eight, three, six, five, seven, spinners,
# Nearest to state: emanation, giovanni, government, presidents, city, minority, states, duke,
# Nearest to up: out, down, off, them, rectangles, back, him, hyena,
# Nearest to he: she, it, they, there, who, i, warwick, consequential,
# Nearest to only: conglomerate, not, first, listens, businessmen, endymion, especially, artur,
# Average loss at step 62000: 3.444063
# Average loss at step 64000: 3.360947
# Average loss at step 66000: 3.349570
# Average loss at step 68000: 3.387340
# Average loss at step 70000: 3.369903
# Nearest to two: three, four, five, eight, six, seven, nine, one,
# Nearest to called: named, attributed, considered, gunpoint, used, newington, known, petrochemicals,
# Nearest to to: would, langmuir, nutation, will, should, could, can, must,
# Nearest to system: systems, gau, position, willed, ionia, corpus, quirks, inhibiting,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to with: between, against, among, libyans, while, dedekind, by, chloride,
# Nearest to d: b, v, aberdare, linz, fidonet, servitude, donald, gomoku,
# Nearest to s: gustave, whose, les, his, connectives, reappeared, ineffectiveness, decimated,
# Nearest to be: been, was, have, become, recombine, by, were, is,
# Nearest to his: her, their, its, my, your, whose, the, our,
# Nearest to also: still, now, often, which, never, officially, usually, sometimes,
# Nearest to one: seven, eight, two, six, three, four, nine, spinners,
# Nearest to state: government, minority, presidents, city, emanation, national, awesome, totals,
# Nearest to up: off, out, down, him, away, back, them, rectangles,
# Nearest to he: she, it, they, there, who, we, consequential, never,
# Nearest to only: artur, listens, osamu, last, conglomerate, no, punishes, montoneros,
# Average loss at step 72000: 3.409591
# Average loss at step 74000: 3.393206
# Average loss at step 76000: 3.350636
# Average loss at step 78000: 3.237596
# Average loss at step 80000: 3.373595
# Nearest to two: three, four, one, five, six, seven, eight, zero,
# Nearest to called: named, used, attributed, known, considered, gunpoint, universalists, antennae,
# Nearest to to: langmuir, nutation, can, would, will, should, silvanus, could,
# Nearest to system: systems, gau, willed, weaponry, format, inhibiting, corpus, position,
# Nearest to seven: five, six, four, eight, nine, three, zero, one,
# Nearest to with: between, among, dedekind, against, while, by, when, although,
# Nearest to d: b, linz, aberdare, servitude, v, bawerk, l, tc,
# Nearest to s: whose, minarets, aloha, cavalier, his, carolyn, superscalar, domo,
# Nearest to be: been, is, become, being, have, refer, was, were,
# Nearest to his: her, their, my, its, your, the, our, bolger,
# Nearest to also: often, still, now, which, below, sometimes, always, never,
# Nearest to one: two, seven, five, four, eight, six, three, nine,
# Nearest to state: national, government, city, southeastern, presidents, town, inaugural, states,
# Nearest to up: off, down, out, them, back, abruptly, him, place,
# Nearest to he: she, it, they, there, who, we, never, consequential,
# Nearest to only: amin, speller, coolest, listens, fully, osamu, first, not,
# Average loss at step 82000: 3.302177
# Average loss at step 84000: 3.342674
# Average loss at step 86000: 3.345242
# Average loss at step 88000: 3.323171
# Average loss at step 90000: 3.239039
# Nearest to two: three, four, seven, five, six, eight, zero, one,
# Nearest to called: named, used, universalists, attributed, organising, known, gunpoint, considered,
# Nearest to to: would, will, avoids, nutation, should, wendy, hgp, could,
# Nearest to system: systems, enforced, gau, format, ionia, resolution, willed, omniglot,
# Nearest to seven: eight, five, four, six, three, nine, two, zero,
# Nearest to with: between, libyans, among, dedekind, lombardi, by, in, stile,
# Nearest to d: b, regulars, aberdare, turkish, linz, bawerk, fidonet, ethel,
# Nearest to s: whose, american, and, however, his, of, aloha, reappeared,
# Nearest to be: become, been, were, have, was, refer, recombine, jolly,
# Nearest to his: her, their, its, my, your, our, the, personal,
# Nearest to also: often, still, now, which, never, always, who, officially,
# Nearest to one: two, three, seven, five, four, six, eight, nine,
# Nearest to state: states, national, government, city, presidents, shaanxi, minority, southeastern,
# Nearest to up: off, out, down, back, them, him, abruptly, together,
# Nearest to he: she, it, they, there, who, we, but, never,
# Nearest to only: first, trauma, artur, listens, last, businessmen, punishes, immediately,
# Average loss at step 92000: 2.745438
# Average loss at step 94000: 3.100216
# Average loss at step 96000: 3.064207
# Average loss at step 98000: 3.219493
# Average loss at step 100000: 3.277969
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to called: named, attributed, universalists, used, petrochemicals, considered, gunpoint, decimated,
# Nearest to to: will, nutation, would, can, should, could, applets, must,
# Nearest to system: systems, willed, format, gau, ionia, enforced, resolution, quirks,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to with: between, by, libyans, among, dedekind, against, unresponsive, like,
# Nearest to d: b, regulars, mike, snorri, p, aberdare, sprinter, fidonet,
# Nearest to s: whose, ineffectiveness, my, lamm, his, although, leonard, interpolated,
# Nearest to be: been, become, was, were, have, is, refer, being,
# Nearest to his: her, their, its, my, your, whose, our, the,
# Nearest to also: often, still, now, always, never, which, usually, actually,
# Nearest to one: two, three, four, five, seven, six, spinners, eight,
# Nearest to state: states, government, city, national, supreme, minority, presidents, goitre,
# Nearest to up: off, out, down, back, them, him, rectangles, abruptly,
# Nearest to he: she, it, they, there, who, but, sometimes, never,
# Nearest to only: not, first, immediately, artur, last, usually, roles, listens,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
