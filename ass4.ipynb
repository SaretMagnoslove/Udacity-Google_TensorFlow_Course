# %%
Deep Learning
=============

Assignment 4
------------

Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.

The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
# Create image size function based on input, filter size, padding and stride
# 2 convolutions only
def output_size_no_pool(input_size, filter_size, padding, conv_stride):
    if padding == 'same':
        padding = -1.00
    elif padding == 'valid':
        padding = 0.00
    else:
        return None
    output_1 = float(((input_size - filter_size - 2*padding) / conv_stride) + 1.00)
    output_2 = float(((output_1 - filter_size - 2*padding) / conv_stride) + 1.00)
    return int(np.ceil(output_2))

patch_size = 5
final_image_size = output_size_no_pool(image_size, patch_size, padding='same', conv_stride=2)
print(final_image_size)
# Out:
# 7

# %%
patch_size = 5
batch_size = 16
# Depth is the number of output channels 
# On the other hand, num_channels is the number of input channels set at 1 previously
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    '''Input data'''
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    '''Variables'''
    # Convolution 1 Layer
    # Input channels: num_channels = 1
    # Output channels: depth = 16
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    # Convolution 2 Layer
    # Input channels: depth = 16
    # Output channels: depth = 16
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    # Fully Connected Layer (Densely Connected Layer)
    # Use neurons to allow processing of entire image
    final_image_size = output_size_no_pool(image_size, patch_size, padding='same', conv_stride=2)
    layer3_weights = tf.Variable(tf.truncated_normal([final_image_size * final_image_size * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    # Readout layer: Softmax Layer
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    '''Model'''
    def model(data):
        # First Convolutional Layer
        conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        
        # Second Convolutional Layer
        conv = tf.nn.conv2d(hidden, layer2_weights, strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)   
        
        # Full Connected Layer
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        
        # Readout Layer: Softmax Layer
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    '''Training computation'''
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels=tf_train_labels))

    '''Optimizer'''
    # Learning rate of 0.05
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    '''Predictions for the training, validation, and test data'''
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.727850
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.8%
# Minibatch loss at step 50: 1.824881
# Minibatch accuracy: 18.8%
# Validation accuracy: 49.9%
# Minibatch loss at step 100: 0.903734
# Minibatch accuracy: 62.5%
# Validation accuracy: 64.5%
# Minibatch loss at step 150: 0.508114
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 200: 1.103662
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 250: 1.162963
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 300: 0.372016
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 350: 0.528605
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 400: 0.298978
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.898923
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 500: 0.771998
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 550: 0.949829
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 600: 0.361411
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 650: 0.807115
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 0.904073
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 750: 0.055311
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.660921
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 850: 0.918343
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 900: 0.789094
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.683817
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000: 0.424003
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Test accuracy: 89.6%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
patch_size = 5
batch_size = 16
# Depth is the number of output channels 
# On the other hand, num_channels is the number of input channels set at 1 previously
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    '''Input data'''
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    '''Variables'''
    # Convolution 1 Layer
    # Input channels: num_channels = 1
    # Output channels: depth = 16
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    # Convolution 2 Layer
    # Input channels: depth = 16
    # Output channels: depth = 16
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    # Fully Connected Layer (Densely Connected Layer)
    # Use neurons to allow processing of entire image
    final_image_size = output_size_no_pool(image_size, patch_size, padding='same', conv_stride=2)
    layer3_weights = tf.Variable(tf.truncated_normal([final_image_size * final_image_size * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    # Readout layer: Softmax Layer
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    '''Model'''
    def model(data):
        # First Convolutional Layer
        conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        
        # Second Convolutional Layer
        conv = tf.nn.conv2d(hidden, layer2_weights, strides=[1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)   
        
        # Full Connected Layer
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        
        # Readout Layer: Softmax Layer
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    '''Training computation'''
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels= tf_train_labels))

    '''Optimizer'''
    # Learning rate of 0.05
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    '''Predictions for the training, validation, and test data'''
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 30000

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 100 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.062900
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 1.211415
# Minibatch accuracy: 56.2%
# Validation accuracy: 64.1%
# Minibatch loss at step 200: 0.892033
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 300: 0.359291
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 400: 0.346228
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 500: 0.639295
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 600: 0.380097
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 700: 1.090785
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 800: 0.678375
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 900: 0.590313
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 1000: 0.477851
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 1100: 0.538209
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 1200: 1.123829
# Minibatch accuracy: 56.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 1300: 0.234335
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 1400: 0.368943
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 1500: 0.651720
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 1600: 1.059605
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 1700: 0.531112
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 1800: 0.301810
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 1900: 0.444306
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2000: 0.080163
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 2100: 0.413201
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 2200: 0.348730
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 2300: 0.665750
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 2400: 0.421581
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 2500: 0.833681
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 2600: 0.224553
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 2700: 0.309336
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 2800: 0.591709
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 2900: 0.256810
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 3000: 0.668192
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 3100: 0.370722
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 3200: 0.420680
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3300: 0.136194
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3400: 0.477548
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 3500: 0.368690
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3600: 0.275148
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 3700: 1.022782
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 3800: 0.004369
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 3900: 0.447856
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4000: 0.485274
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 4100: 0.478260
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 4200: 0.622898
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 4300: 0.855076
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 4400: 1.198726
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 4500: 0.583223
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 4600: 0.653972
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 4700: 0.432262
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 4800: 0.402826
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 4900: 0.216138
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 5000: 1.193467
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 5100: 0.382737
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 5200: 0.246500
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 5300: 0.343025
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 5400: 0.323753
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 5500: 0.776721
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 5600: 0.382823
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 5700: 0.539838
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 5800: 0.124252
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 5900: 0.510010
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 6000: 0.037969
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 6100: 0.683706
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 6200: 1.166892
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 6300: 0.710255
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 6400: 0.126850
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 6500: 0.967476
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 6600: 0.293531
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 6700: 0.240125
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 6800: 0.802910
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 6900: 0.505321
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 7000: 0.645405
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 7100: 0.654933
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 7200: 0.349106
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 7300: 0.755847
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 7400: 0.020833
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 7500: 0.201198
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 7600: 0.479667
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 7700: 0.092451
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 7800: 0.390694
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 7900: 0.082061
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 8000: 0.441944
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 8100: 0.385340
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 8200: 0.276965
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 8300: 0.369429
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 8400: 0.409486
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 8500: 0.254833
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 8600: 0.301420
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 8700: 0.232227
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 8800: 0.203481
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 8900: 0.431839
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 9000: 0.291033
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 9100: 0.320508
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 9200: 0.180308
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 9300: 0.789803
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 9400: 0.445988
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 9500: 0.121042
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 9600: 0.303333
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 9700: 0.159548
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 9800: 0.486506
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 9900: 0.670712
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 10000: 0.132906
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 10100: 0.297666
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 10200: 0.144426
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 10300: 0.189546
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 10400: 0.310511
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 10500: 0.223343
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 10600: 0.692749
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 10700: 0.041178
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 10800: 0.247308
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 10900: 0.256307
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 11000: 0.097126
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 11100: 0.104622
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 11200: 0.191431
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 11300: 0.241250
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 11400: 0.237813
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 11500: 0.348706
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 11600: 0.354895
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 11700: 0.983143
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 11800: 0.009202
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 11900: 0.416321
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 12000: 0.423714
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 12100: 0.542385
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 12200: 0.412751
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 12300: 0.304000
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 12400: 0.029924
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 12500: 0.710895
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 12600: 0.372441
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 12700: 0.383232
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 12800: 0.184301
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 12900: 0.108467
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 13000: 0.161745
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 13100: 0.153202
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 13200: 0.263834
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 13300: 0.192487
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 13400: 0.504172
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 13500: 0.304748
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 13600: 0.552229
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 13700: 0.253302
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 13800: 0.063369
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 13900: 0.114175
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 14000: 0.014750
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 14100: 0.619884
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 14200: 0.173440
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 14300: 0.198320
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 14400: 0.289752
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 14500: 0.401837
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 14600: 0.065216
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 14700: 0.250023
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 14800: 0.212149
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 14900: 0.353783
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 15000: 0.284845
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 15100: 0.150516
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 15200: 0.027053
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 15300: 0.181461
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 15400: 0.601313
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 15500: 0.177247
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 15600: 0.363862
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 15700: 0.163444
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 15800: 0.036544
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 15900: 0.360097
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 16000: 0.906037
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 16100: 0.374773
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 16200: 0.698336
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 16300: 0.312372
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 16400: 0.741522
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 16500: 0.014290
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 16600: 0.282394
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 16700: 0.351795
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 16800: 0.797052
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 16900: 0.800554
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 17000: 0.216812
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 17100: 0.188904
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 17200: 0.374991
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 17300: 0.177282
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 17400: 0.559248
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 17500: 0.425003
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 17600: 0.525467
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.1%
# Minibatch loss at step 17700: 0.444627
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 17800: 0.448693
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 17900: 0.397792
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 18000: 0.281473
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 18100: 0.599178
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 18200: 0.549120
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 18300: 0.085824
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 18400: 0.713597
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 18500: 0.132699
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 18600: 0.248442
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 18700: 0.110933
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 18800: 0.421399
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 18900: 0.030808
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 19000: 0.526904
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 19100: 0.082534
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 19200: 0.222397
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 19300: 0.158419
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 19400: 0.505317
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 19500: 0.472942
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 19600: 0.311436
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 19700: 0.192199
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 19800: 0.140877
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 19900: 0.039748
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 20000: 0.206803
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 20100: 0.543489
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 20200: 0.367733
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 20300: 0.224955
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 20400: 0.337491
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 20500: 0.055720
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 20600: 0.353718
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 20700: 0.549759
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 20800: 0.235680
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 20900: 0.041149
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 21000: 0.059630
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 21100: 0.054460
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 21200: 0.200636
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 21300: 0.635729
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 21400: 0.690967
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 21500: 0.044702
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 21600: 0.122416
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 21700: 0.320138
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 21800: 0.327439
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 21900: 0.240024
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 22000: 0.197397
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 22100: 0.024429
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 22200: 0.483329
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 22300: 0.004521
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 22400: 0.236071
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 22500: 0.295277
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 22600: 0.668697
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 22700: 0.194987
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 22800: 0.080320
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 22900: 0.216137
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 23000: 0.385587
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 23100: 0.218107
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 23200: 0.327627
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 23300: 0.788766
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 23400: 0.526573
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 23500: 0.259363
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 23600: 0.355195
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 23700: 0.274816
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 23800: 0.261926
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 23900: 0.382529
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 24000: 0.123175
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 24100: 0.566194
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 24200: 0.456921
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 24300: 0.713803
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 24400: 0.212447
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 24500: 0.585762
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 24600: 0.274193
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 24700: 0.286354
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 24800: 0.254358
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 24900: 0.731607
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 25000: 0.446245
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 25100: 0.290334
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 25200: 0.467604
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 25300: 0.292498
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 25400: 0.120781
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 25500: 0.158656
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 25600: 0.187314
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 25700: 0.665261
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 25800: 0.095855
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 25900: 0.189499
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 26000: 0.246140
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 26100: 0.387455
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 26200: 0.128860
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 26300: 0.394731
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 26400: 0.101400
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 26500: 0.063316
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 26600: 0.406959
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 26700: 0.092756
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 26800: 0.020067
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 26900: 0.498706
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 27000: 0.002718
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 27100: 0.326640
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 27200: 0.087858
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 27300: 0.115346
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 27400: 0.907251
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 27500: 0.116021
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 27600: 0.487558
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 27700: 0.528738
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 27800: 0.181216
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# Minibatch loss at step 27900: 0.253679
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 28000: 0.337987
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 28100: 0.307290
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 28200: 0.070754
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 28300: 0.492318
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 28400: 0.263983
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 28500: 0.506307
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 28600: 0.594473
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 28700: 0.189759
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 28800: 0.316282
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 28900: 0.422544
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 29000: 0.041823
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 29100: 0.003044
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 29200: 0.104170
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 29300: 0.241313
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 29400: 0.080639
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 29500: 0.326136
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 29600: 0.010235
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 29700: 0.439379
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 29800: 0.149295
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 29900: 0.144104
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Test accuracy: 95.4%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
image_size = 28

def output_size_pool(input_size, conv_filter_size, pool_filter_size, padding, conv_stride, pool_stride):
    if padding == 'same':
        padding = -1.00
    elif padding == 'valid':
        padding = 0.00
    else:
        return None

    output_1 = (((input_size - conv_filter_size - 2*padding) / conv_stride) + 1.00)

    output_2 = (((output_1 - pool_filter_size - 2*padding) / pool_stride) + 1.00)    

    output_3 = (((output_2 - conv_filter_size - 2*padding) / conv_stride) + 1.00)

    output_4 = (((output_3 - pool_filter_size - 2*padding) / pool_stride) + 1.00)  
    return int(output_4)

final_image_size = output_size_pool(input_size=image_size, conv_filter_size=5, pool_filter_size=2, padding='valid', conv_stride=1, pool_stride=2)
print(final_image_size)
# Out:
# 4

# %%
batch_size = 16
# Depth is the number of output channels 
# On the other hand, num_channels is the number of input channels set at 1 previously
depth = 32
num_hidden = 64
beta = 0.001

graph = tf.Graph()

with graph.as_default():

    '''Input data'''
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    '''Variables'''
    # Convolution 1 Layer
    # Input channels: num_channels = 1
    # Output channels: depth = 16
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    
    # Convolution 2 Layer
    # Input channels: depth = 16
    # Output channels: depth = 16
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    # First Fully Connected Layer (Densely Connected Layer)
    # Use neurons to allow processing of entire image
    final_image_size = output_size_pool(input_size=image_size, conv_filter_size=5, pool_filter_size=2, padding='valid', conv_stride=1, pool_stride=2)
    layer3_weights = tf.Variable(tf.truncated_normal([final_image_size * final_image_size * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    # Second Fully Connected Layer
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_hidden], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    # Readout layer: Softmax Layer
    layer5_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    '''Model'''
    def model(data):
        # First Convolutional Layer with Pooling
        conv_1 = tf.nn.conv2d(data, layer1_weights, strides=[1, 1, 1, 1], padding='VALID')
        hidden_1 = tf.nn.relu(conv_1 + layer1_biases)
        pool_1 = tf.nn.avg_pool(hidden_1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        
        # Second Convolutional Layer with Pooling
        conv_2 = tf.nn.conv2d(pool_1, layer2_weights, strides=[1, 1, 1, 1], padding='VALID')
        hidden_2 = tf.nn.relu(conv_2 + layer2_biases)
        pool_2 = tf.nn.avg_pool(hidden_2, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        
        # First Fully Connected Layer
        shape = pool_2.get_shape().as_list()
        reshape = tf.reshape(pool_2, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        keep_prob = 0.5
        hidden_drop = tf.nn.dropout(hidden, keep_prob)
        
        # Second Fully Connected Layer
        hidden_2 = tf.nn.relu(tf.matmul(hidden_drop, layer4_weights) + layer4_biases)
        hidden_2_drop = tf.nn.dropout(hidden_2, keep_prob)
        
        # Readout Layer: Softmax Layer
        return tf.matmul(hidden_2_drop, layer5_weights) + layer5_biases

    '''Training computation'''
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits,labels= tf_train_labels))
    # Loss function with L2 Regularization 
    # regularizers = tf.nn.l2_loss(layer4_weights) + \
                   # tf.nn.l2_loss(layer5_weights)
    # loss = tf.reduce_mean(loss + beta * regularizers)

    '''Optimizer'''
    # Decaying learning rate
    global_step = tf.Variable(0)  # count the number of steps taken.
    start_learning_rate = 0.05
    learning_rate = tf.train.exponential_decay(start_learning_rate, global_step, 100000, 0.96, staircase=True)

    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    '''Predictions for the training, validation, and test data'''
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 30000

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 5000 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From c:\users\avi\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\util\tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.019213
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 5000: 1.302980
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 10000: 0.206831
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 15000: 0.531899
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 20000: 0.364675
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 25000: 0.748193
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Test accuracy: 92.3%
